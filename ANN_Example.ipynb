# %% [markdown]
# <a href="https://colab.research.google.com/github/AmmarMalik93/MachineLearningSabKayLiey/blob/master/ANN_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MNIST Handwritten Digit recognition using ANNs in Tensorflow(Keras)

# %% [markdown]
# Load required libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
# %tensorflow_version 2.x
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Load and Normalize MNIST dataset

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train/255.0 # Normalizing between 0 and 1
X_test = X_test/255.0 # Normalizing between 0 and 1


print("X_train shape", X_train.shape)
print("y_train shape", y_train.shape)
print("X_test shape", X_test.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (60000, 28, 28)
# y_train shape (60000,)
# X_test shape (10000, 28, 28)
# y_test shape (10000,)

# %% [markdown]
# Lets Display some images

# %%
fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(10, 6), subplot_kw={'xticks': [], 'yticks': []})
i = 0
for ax in axs.flat:
  ax.imshow(X_train[i,:,:], cmap='Greys')
  i += 1

# %% [markdown]
# Now reshape the digits to vectors

# %%
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1]*X_train.shape[2]) 
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1]*X_test.shape[2])

print("New X_train shape", X_train.shape)
print("New X_test shape", X_test.shape)
# Out:
# New X_train shape (60000, 784)
# New X_test shape (10000, 784)

# %%
num_class = 10
Y_train = to_categorical(y_train, num_class) 
Y_test = to_categorical(y_test, num_class)

# %%
model = keras.Sequential()
model.add(layers.Dense(16, activation='sigmoid', input_dim=X_train.shape[1]))
model.add(layers.Dense(16, activation='sigmoid'))
model.add(layers.Dense(num_class, activation='softmax'))
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                12560
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                170
# =================================================================
# Total params: 13,002
# Trainable params: 13,002
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, Y_train, epochs = 50, verbose = 1, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 2.2807 - accuracy: 0.2193 - val_loss: 2.2181 - val_accuracy: 0.3566
# Epoch 2/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 2.1291 - accuracy: 0.4879 - val_loss: 1.9987 - val_accuracy: 0.5401
# Epoch 3/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.8129 - accuracy: 0.5796 - val_loss: 1.6035 - val_accuracy: 0.6148
# Epoch 4/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.4216 - accuracy: 0.6451 - val_loss: 1.2435 - val_accuracy: 0.6889
# Epoch 5/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 1.1226 - accuracy: 0.7104 - val_loss: 1.0034 - val_accuracy: 0.7443
# Epoch 6/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.9341 - accuracy: 0.7575 - val_loss: 0.8539 - val_accuracy: 0.7782
# Epoch 7/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.8102 - accuracy: 0.7912 - val_loss: 0.7473 - val_accuracy: 0.8114
# Epoch 8/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.7180 - accuracy: 0.8184 - val_loss: 0.6640 - val_accuracy: 0.8314
# Epoch 9/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.6450 - accuracy: 0.8379 - val_loss: 0.5975 - val_accuracy: 0.8544
# Epoch 10/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5867 - accuracy: 0.8528 - val_loss: 0.5456 - val_accuracy: 0.8676
# Epoch 11/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5398 - accuracy: 0.8644 - val_loss: 0.5031 - val_accuracy: 0.8746
# Epoch 12/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5020 - accuracy: 0.8733 - val_loss: 0.4691 - val_accuracy: 0.8809
# Epoch 13/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4713 - accuracy: 0.8813 - val_loss: 0.4415 - val_accuracy: 0.8868
# Epoch 14/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4460 - accuracy: 0.8863 - val_loss: 0.4194 - val_accuracy: 0.8901
# Epoch 15/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4249 - accuracy: 0.8907 - val_loss: 0.4017 - val_accuracy: 0.8943
# Epoch 16/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4069 - accuracy: 0.8946 - val_loss: 0.3862 - val_accuracy: 0.8967
# Epoch 17/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3914 - accuracy: 0.8977 - val_loss: 0.3719 - val_accuracy: 0.8994
# Epoch 18/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3780 - accuracy: 0.8999 - val_loss: 0.3603 - val_accuracy: 0.9006
# Epoch 19/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3659 - accuracy: 0.9022 - val_loss: 0.3499 - val_accuracy: 0.9031
# Epoch 20/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3551 - accuracy: 0.9049 - val_loss: 0.3402 - val_accuracy: 0.9057
# Epoch 21/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3454 - accuracy: 0.9067 - val_loss: 0.3318 - val_accuracy: 0.9079
# Epoch 22/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3365 - accuracy: 0.9082 - val_loss: 0.3242 - val_accuracy: 0.9105
# Epoch 23/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3283 - accuracy: 0.9110 - val_loss: 0.3168 - val_accuracy: 0.9119
# Epoch 24/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3206 - accuracy: 0.9125 - val_loss: 0.3107 - val_accuracy: 0.9138
# Epoch 25/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3134 - accuracy: 0.9143 - val_loss: 0.3044 - val_accuracy: 0.9153
# Epoch 26/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3068 - accuracy: 0.9158 - val_loss: 0.2984 - val_accuracy: 0.9178
# Epoch 27/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3004 - accuracy: 0.9176 - val_loss: 0.2932 - val_accuracy: 0.9191
# Epoch 28/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2943 - accuracy: 0.9190 - val_loss: 0.2883 - val_accuracy: 0.9205
# Epoch 29/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2887 - accuracy: 0.9206 - val_loss: 0.2829 - val_accuracy: 0.9219
# Epoch 30/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2833 - accuracy: 0.9218 - val_loss: 0.2784 - val_accuracy: 0.9230
# Epoch 31/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2781 - accuracy: 0.9230 - val_loss: 0.2746 - val_accuracy: 0.9238
# Epoch 32/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2733 - accuracy: 0.9246 - val_loss: 0.2702 - val_accuracy: 0.9243
# Epoch 33/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2687 - accuracy: 0.9251 - val_loss: 0.2664 - val_accuracy: 0.9248
# Epoch 34/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2642 - accuracy: 0.9264 - val_loss: 0.2622 - val_accuracy: 0.9270
# Epoch 35/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2599 - accuracy: 0.9282 - val_loss: 0.2590 - val_accuracy: 0.9264
# Epoch 36/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2559 - accuracy: 0.9288 - val_loss: 0.2552 - val_accuracy: 0.9285
# Epoch 37/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2520 - accuracy: 0.9296 - val_loss: 0.2520 - val_accuracy: 0.9286
# Epoch 38/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2482 - accuracy: 0.9306 - val_loss: 0.2497 - val_accuracy: 0.9304
# Epoch 39/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2448 - accuracy: 0.9323 - val_loss: 0.2470 - val_accuracy: 0.9299
# Epoch 40/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2414 - accuracy: 0.9326 - val_loss: 0.2433 - val_accuracy: 0.9309
# Epoch 41/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2381 - accuracy: 0.9338 - val_loss: 0.2411 - val_accuracy: 0.9323
# Epoch 42/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2352 - accuracy: 0.9345 - val_loss: 0.2383 - val_accuracy: 0.9334
# Epoch 43/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2322 - accuracy: 0.9353 - val_loss: 0.2366 - val_accuracy: 0.9334
# Epoch 44/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2294 - accuracy: 0.9360 - val_loss: 0.2341 - val_accuracy: 0.9348
# Epoch 45/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2268 - accuracy: 0.9367 - val_loss: 0.2315 - val_accuracy: 0.9358
# Epoch 46/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2242 - accuracy: 0.9374 - val_loss: 0.2301 - val_accuracy: 0.9354
# Epoch 47/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2217 - accuracy: 0.9378 - val_loss: 0.2276 - val_accuracy: 0.9371
# Epoch 48/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2193 - accuracy: 0.9388 - val_loss: 0.2264 - val_accuracy: 0.9363
# Epoch 49/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2171 - accuracy: 0.9394 - val_loss: 0.2240 - val_accuracy: 0.9370
# Epoch 50/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2148 - accuracy: 0.9397 - val_loss: 0.2220 - val_accuracy: 0.9373

# %%
# plot learning curves
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(15, 6))
#ax1.set_title('Learning Curves')
ax1.set_xlabel('Epoch', fontsize=18)
ax1.set_ylabel('Cross Entropy', fontsize=18)
ax1.grid(which='both')
ax1.minorticks_on()
ax1.plot(history.history['loss'], label='train_loss')
ax1.plot(history.history['val_loss'], label='val_loss')
ax1.tick_params(labelsize=15)
ax1.legend(loc='best',fontsize=15)

ax2.set_xlabel('Epoch', fontsize=18)
ax2.set_ylabel('Accuracy', fontsize=18)
ax2.grid(which='both')
ax2.minorticks_on()
ax2.plot(history.history['accuracy'], label='train_accuracy')
ax2.plot(history.history['val_accuracy'], label='val_accuracy')
ax2.tick_params(labelsize=15)
ax2.legend(loc='best',fontsize=15)
fig.suptitle('Model Performance', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Model Performance')

# %% [markdown]
# **Confusion Matrix**

# %%
Y_Pred = np.argmax(model.predict(X_test), axis=-1)
df = pd.DataFrame([y_test,Y_Pred]).T
df.columns = ['Test','Predicted']
confusion_matrix = pd.crosstab(df['Test'], df['Predicted'], rownames=['Test'], colnames=['Predicted'])

fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(confusion_matrix, annot=True, fmt='d', ax=ax, cmap="YlGnBu")
plt.show()

# %% [markdown]
# Plot some of the misclassified digits.

# %%
missed = np.where(y_test != Y_Pred)[0] # indices of miss classified imaged

missed_imgs = X_test[missed,:].reshape(-1,28,28) # missed images from test dataset
missed_true = y_test[missed] # true labels of missed images
missed_pred = Y_Pred[missed] # predicted labels of missed images

# %%
fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(10, 8), subplot_kw={'xticks': [], 'yticks': []})
i = 0
for ax in axs.flat:
  ax.imshow(missed_imgs[i,:,:], cmap='Greys')
  ax.set_title('Predicted:%d, True:%d'%(missed_pred[i],missed_true[i]))
  i += 1
